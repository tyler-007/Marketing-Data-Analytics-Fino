# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rcs= pd.read_csv('Fino Dataset- Aayush - rcsf.csv')

# %%
rcs.head()
# Out:
#                  Product      Date        Campaign Name  \
# 0  Shubh Savings Account   9th Nov    Shubh Renewal Eng
# 1  Shubh Savings Account   9th Nov  Shubh Renewal Hindi
# 2                FinoPay  10th Nov  Dhanteras_Digi_Gold
# 3  Shubh Savings Account  13th Nov    Shubh Renewal Eng
# 4  Shubh Savings Account  13th Nov    Shubh Renewal Hin
#
#          Target Audience Message  Total  Delivered   Read  Failed  Pending  \
# 0  Non Renewal Customers     NaN   4133       3870   1310       2      261
# 1  Non Renewal Customers     NaN  28118      26191   8713      30     1897
# 2       Active Customers     NaN  49949      47461  16137     104     2384
# 3  Non Renewal Customers     NaN   3933       3683    978       4      246
# 4  Non Renewal Customers     NaN  26841      24800   5792      36     2005
#
#       Status
# 0  Completed
# 1  Completed
# 2  Completed
# 3  Completed
# 4  Completed

# %%
rcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product          60 non-null     object
#  1   Date             60 non-null     object
#  2   Campaign Name    60 non-null     object
#  3   Target Audience  60 non-null     object
#  4   Message          50 non-null     object
#  5   Total            60 non-null     int64
#  6   Delivered        60 non-null     int64
#  7   Read             60 non-null     int64
#  8   Failed           60 non-null     int64
#  9   Pending          60 non-null     int64
#  10  Status           60 non-null     object
# dtypes: int64(5), object(6)
# memory usage: 5.3+ KB

# %%
rcs.describe()
# Out:
#               Total     Delivered          Read       Failed      Pending
# count     60.000000     60.000000     60.000000     60.00000    60.000000
# mean   17687.333333  16408.633333   4505.383333    782.85000   495.850000
# std    16067.013895  15070.905018   4602.641530   2877.10328  1012.308887
# min       77.000000      3.000000      0.000000      0.00000 -3357.000000
# 25%     2672.250000   2014.500000    673.500000     24.00000     0.000000
# 50%    17505.000000  15686.500000   3492.000000     51.50000   346.500000
# 75%    28784.750000  26288.750000   6390.250000    343.00000  1006.000000
# max    89310.000000  80605.000000  22452.000000  20561.00000  3306.000000

# %%
check = 0
for index, row in rcs.iterrows():
    if row['Total'] == row['Delivered'] + row['Failed'] + row['Pending']:
        check += 1

print(check)
# Out:
# 60

# %%
rcs['Rate']=(rcs['Read']/rcs["Delivered"]*100)

# %%
rcs['Rate']
# Out:
# 0     33.850129
# 1     33.267153
# 2     34.000548
# 3     26.554439
# 4     23.354839
# 5     32.564206
# 6     23.746212
# 7     24.701740
# 8     29.168677
# 9     24.907902
# 10    37.763811
# 11    35.989621
# 12    40.731995
# 13    32.759540
# 14    25.634419
# 15    28.260566
# 16    38.271605
# 17    26.063201
# 18    28.315995
# 19    24.369798
# 20    28.369454
# 21    20.810088
# 22    18.326512
# 23    26.746507
# 24    37.500000
# 25    29.032258
# 26    27.074500
# 27    29.310345
# 28    29.268293
# 29    28.571429
# 30    23.963156
# 31    20.161672
# 32    18.382808
# 33    20.838612
# 34    29.514488
# 35    29.729730
# 36    27.944320
# 37    23.529412
# 38    21.942295
# 39    19.305589
# 40    17.770445
# 41     0.000000
# 42    21.342866
# 43    28.521806
# 44    25.000000
# 45    33.000200
# 46    19.296447
# 47    16.725233
# 48    28.224011
# 49    19.037031
# 50    18.142077
# 51    30.119177
# 52    30.625000
# 53    34.290030
# 54    39.527149
# 55    32.164032
# 56    35.625000
# 57    29.839741
# 58    18.348178
# 59    27.854351
# Name: Rate, dtype: float64

# %% [markdown]
# view the data grouped by day

# %%
rcs['Campaign Name'].nunique()
# Out:
# 35

# %%
rcs.head(12)
# Out:
#                   Product        Date  \
# 0   Shubh Savings Account     9th Nov
# 1   Shubh Savings Account     9th Nov
# 2                 FinoPay    10th Nov
# 3   Shubh Savings Account    13th Nov
# 4   Shubh Savings Account    13th Nov
# 5                 FinoPay    15th Nov
# 6                 FinoPay    16th Nov
# 7                 FinoPay    20th Nov
# 8       Bhavishya Account    23rd Nov
# 9       Bhavishya Account    23rd Nov
# 10          MAB + FinoPay  09-12-2023
# 11                 PMJJBY  09-12-2023
#
#                                      Campaign Name            Target Audience  \
# 0                                Shubh Renewal Eng      Non Renewal Customers
# 1                              Shubh Renewal Hindi      Non Renewal Customers
# 2                              Dhanteras_Digi_Gold           Active Customers
# 3                                Shubh Renewal Eng      Non Renewal Customers
# 4                                Shubh Renewal Hin      Non Renewal Customers
# 5              100% cashback november_15thNov23_Mp       FinoPay Refer & Earn
# 6   RCS campaigns for Funding and VKYC_16thNov22_1       Non Funded Customers
# 7                               rekyc through vkyc    ReKyc Pending Customers
# 8                        Bhavishya_newly_onboarded  Newly Onboarded Customers
# 9                                Bhavishya renewal  Renewal Pending Customers
# 10                            AS_Christmas_Bonanza                  Merchants
# 11                                       VR_PMJJBY                  Merchants
#
#                                               Message  Total  Delivered  \
# 0                                                 NaN   4133       3870
# 1                                                 NaN  28118      26191
# 2                                                 NaN  49949      47461
# 3                                                 NaN   3933       3683
# 4                                                 NaN  26841      24800
# 5                                                 NaN  33195      32201
# 6                                                 NaN  10982      10229
# 7                                                 NaN  20175      19027
# 8                                                 NaN  24763      22795
# 9                                                 NaN  14231      13301
# 10  This December,\nEarn big with Christmas Bonanz...  31159      30230
# 11  Pradhan Mantri Jeevann Jyoti Bima Yojana (PMJJ...  30184      29289
#
#      Read  Failed  Pending     Status       Rate
# 0    1310       2      261  Completed  33.850129
# 1    8713      30     1897  Completed  33.267153
# 2   16137     104     2384  Completed  34.000548
# 3     978       4      246  Completed  26.554439
# 4    5792      36     2005  Completed  23.354839
# 5   10486      70      924  Completed  32.564206
# 6    2429      12      741  Completed  23.746212
# 7    4700      15     1133  Completed  24.701740
# 8    6649      33     1935  Completed  29.168677
# 9    3313      39      891  Completed  24.907902
# 10  11416      61      868  Completed  37.763811
# 11  10541     131      764  Completed  35.989621

# %%
from datetime import datetime

def convert_to_uniform_format(date):
    try:
        return pd.to_datetime(date).strftime('%d-%m-%Y')
    except ValueError:
        parts = date.split()
        day = parts[0][:-2]  
        month_name = parts[1]
        month_number = datetime.strptime(month_name, '%b').month  
        return f'{day:02d}-{month_number:02d}-2023'  

rcs['Date'] = rcs['Date'].apply(convert_to_uniform_format)
# Out:
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_2944/4098069062.py:5: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   return pd.to_datetime(date).strftime('%d-%m-%Y')

# %%
rcs['Date']
# Out:
# 0     09-11-2023
# 1     09-11-2023
# 2     10-11-2023
# 3     13-11-2023
# 4     13-11-2023
# 5     15-11-2023
# 6     16-11-2023
# 7     20-11-2023
# 8     23-11-2023
# 9     23-11-2023
# 10    09-12-2023
# 11    09-12-2023
# 12    13-12-2023
# 13    15-12-2023
# 14    15-12-2023
# 15    15-12-2023
# 16    18-12-2023
# 17    18-12-2023
# 18    18-12-2023
# 19    19-12-2023
# 20    19-12-2023
# 21    19-12-2023
# 22    19-12-2023
# 23    19-12-2023
# 24    19-12-2023
# 25    20-12-2023
# 26    20-12-2023
# 27    20-12-2023
# 28    21-12-2023
# 29    23-12-2023
# 30    23-12-2023
# 31    23-12-2023
# 32    23-12-2023
# 33    23-12-2023
# 34    23-12-2023
# 35    26-12-2023
# 36    27-12-2023
# 37    27-12-2023
# 38    27-12-2023
# 39    27-12-2023
# 40    27-12-2023
# 41    28-12-2023
# 42    28-12-2023
# 43    28-12-2023
# 44    29-12-2023
# 45    02-01-2024
# 46    03-01-2024
# 47    03-01-2024
# 48    03-01-2024
# 49    09-01-2024
# 50    09-01-2024
# 51    09-01-2024
# 52    17-01-2024
# 53    17-01-2024
# 54    19-01-2024
# 55    23-01-2024
# 56    23-01-2024
# 57    23-01-2024
# 58    23-01-2024
# 59    23-01-2024
# Name: Date, dtype: object

# %%
from datetime import datetime

rcs['Date'] = pd.to_datetime(rcs['Date'], format='%d-%m-%Y')
rcs['Day'] = rcs['Date'].dt.strftime("%A")
print(rcs['Day'].value_counts())
# Out:
# Day
# Tuesday      16
# Wednesday    15
# Thursday      9
# Saturday      8
# Friday        6
# Monday        6
# Name: count, dtype: int64

# %%
Enagement_per_day = rcs.groupby('Day')['Rate'].mean().reset_index()
Enagement_per_day = Enagement_per_day.sort_values(by= 'Rate')

# %%
company_colors = ['#6610f2', '#6f42c1', '#e83e8c'] 
plt.figure(figsize=(10, 6))
plt.bar(Enagement_per_day['Day'], Enagement_per_day['Rate'], color=company_colors[1])
plt.title('Average Rate by Day')
plt.xlabel('Days')
plt.ylabel('Average Rate')
plt.show()

# %% [markdown]
# Why Friday has higher rate? Market closed? and only 6 campia

# %%
rcs['Target Audience'].nunique()
# Out:
# 16

# %%
tgt_audience = rcs.groupby('Target Audience')['Rate'].mean().reset_index()
plt.figure(figsize=(11, 6))
plt.bar(tgt_audience['Target Audience'], tgt_audience['Rate'], color=company_colors[0])
plt.title('Average Rate by tgt audience')
plt.xlabel('tgt')
plt.xticks(rotation='vertical')
plt.ylabel('Average Rate')
plt.show()

# %%
x=rcs['Target Audience'].value_counts()
plt.bar(x.index,x.values, color= company_colors[0])
plt.xlabel('Different Target audience')
plt.ylabel('Count')
plt.xticks(rotation='vertical')

plt.title('Count of different Tagret audience ')
# Out:
# Text(0.5, 1.0, 'Count of different Tagret audience ')

# %%
tgt_campaign = rcs.groupby('Campaign Name')[['Rate','Total']].mean().reset_index()
plt.figure(figsize=(11, 6))
plt.bar(tgt_campaign['Campaign Name'],tgt_campaign['Rate'], color=company_colors[0])
plt.title('Average Rate by tgt audience')
plt.xlabel('tgt')
plt.xticks(rotation='vertical')
plt.ylabel('Average Rate')
plt.show()

# %%
tgt_campaign_sorted = tgt_campaign.sort_values(by='Rate')

top_5 = tgt_campaign_sorted.tail(5)
bottom_5 = tgt_campaign_sorted.head(5)

top_bottom_5 = pd.concat([top_5, bottom_5])

plt.figure(figsize=(11, 6))
plt.bar(top_bottom_5['Campaign Name'], top_bottom_5['Rate'], color=company_colors[0])
plt.title('Average Rate by tgt audience (Top 5 and Bottom 5)')
plt.xlabel('tgt')
plt.xticks(rotation='vertical')
plt.ylabel('Average Rate')
plt.show()

# %%
tgt_campaign_sorted = tgt_campaign.sort_values(by='Rate')

top_5 = tgt_campaign_sorted.tail(5)
bottom_5 = tgt_campaign_sorted.head(5)

top_bottom_5 = pd.concat([top_5, bottom_5])

plt.figure(figsize=(11, 6))
plt.bar(top_bottom_5['Campaign Name'], top_bottom_5['Total'], color=company_colors[1])
plt.title('Average Rate by tgt audience (Top 5 and Bottom 5)')
plt.xlabel('tgt')
plt.xticks(rotation='vertical')
plt.ylabel('Average Rate')
plt.show()

# %% [markdown]
# Annuity Payout	19-01-2024	English_annuity_pyot	Merchant Base	KHATA KHOLNE KE SAATH AUR BAAD, SADAIV SAATH. 1.if a customer keeps maximum balance in account. 2. customer renewing account. 3.if a customer uses a Finopay app.	31364	30369	12004	989	6	Running
#
# 30% + turnout rate. with 30k+ users(Merchant Base).

# %%
rcs[rcs['Campaign Name']=='English_annuity_pyot']
# Out:
#            Product       Date         Campaign Name Target Audience  \
# 54  Annuity Payout 2024-01-19  English_annuity_pyot   Merchant Base
#
#                                               Message  Total  Delivered  \
# 54  KHATA KHOLNE KE SAATH AUR BAAD, SADAIV SAATH. ...  31364      30369
#
#      Read  Failed  Pending   Status       Rate     Day  Language_Category
# 54  12004     989        6  Running  39.527149  Friday                2.0

# %% [markdown]
# Ideal way - Hinglish text and friday.
# Merchant Base religion?

# %%
rcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product            60 non-null     object
#  1   Date               60 non-null     datetime64[ns]
#  2   Campaign Name      60 non-null     object
#  3   Target Audience    60 non-null     object
#  4   Message            50 non-null     object
#  5   Total              60 non-null     int64
#  6   Delivered          60 non-null     int64
#  7   Read               60 non-null     int64
#  8   Failed             60 non-null     int64
#  9   Pending            60 non-null     int64
#  10  Status             60 non-null     object
#  11  Rate               60 non-null     float64
#  12  Day                60 non-null     object
#  13  Language_Category  50 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(6)
# memory usage: 6.7+ KB

# %%
rcs['Day'].value_counts()
# Out:
# Day
# Tuesday      16
# Wednesday    15
# Thursday      9
# Saturday      8
# Friday        6
# Monday        6
# Name: count, dtype: int64

# %%
print(rcs['Total'].describe())
print(rcs['Rate'].mean())
# Out:
# count       60.000000
# mean     17687.333333
# std      16067.013895
# min         77.000000
# 25%       2672.250000
# 50%      17505.000000
# 75%      28784.750000
# max      89310.000000
# Name: Total, dtype: float64
# 27.000843969706814

# %%
rcs.sort_values(by= 'Rate',ascending=False)
# Out:
#                    Product       Date  \
# 59                   Day 1 2024-01-23
# 2                  FinoPay 2023-11-10
# 45             Fancode OTT 2024-01-02
# 5                  FinoPay 2023-11-15
# 18    Bhavishya * Braingym 2023-12-18
# 21    Bhavishya * Braingym 2023-12-19
# 54          Annuity Payout 2024-01-19
# 31    Bhavishya * Braingym 2023-12-23
# 10           MAB + FinoPay 2023-12-09
# 39    Bhavishya * Braingym 2023-12-27
# 11                  PMJJBY 2023-12-09
# 15       Christmas Bonanza 2023-12-15
# 46      Bhavishya*Braingym 2024-01-03
# 49      Bhavishya*Braingym 2024-01-09
# 34           MAB + FinoPay 2023-12-23
# 57      Bhavishya*Braingym 2024-01-23
# 1    Shubh Savings Account 2023-11-09
# 4    Shubh Savings Account 2023-11-13
# 8        Bhavishya Account 2023-11-23
# 12         Balance Buildup 2023-12-13
# 14         Balance Buildup 2023-12-15
# 13         Balance Buildup 2023-12-15
# 20         Balance Buildup 2023-12-19
# 27         Balance Buildup 2023-12-20
# 30         Balance Buildup 2023-12-23
# 36         Balance Buildup 2023-12-27
# 42         Balance Buildup 2023-12-28
# 7                  FinoPay 2023-11-20
# 19      ReKYC through VKYC 2023-12-19
# 33      ReKYC through VKYC 2023-12-23
# 38      ReKYC through VKYC 2023-12-27
# 9        Bhavishya Account 2023-11-23
# 17    Bhavishya * Braingym 2023-12-18
# 22    Bhavishya * Braingym 2023-12-19
# 32    Bhavishya * Braingym 2023-12-23
# 40    Bhavishya * Braingym 2023-12-27
# 47      Bhavishya*Braingym 2024-01-03
# 50      Bhavishya*Braingym 2024-01-09
# 6                  FinoPay 2023-11-16
# 51                  Day 13 2024-01-09
# 58      Bhavishya*Braingym 2024-01-23
# 48                   Day 9 2024-01-03
# 0    Shubh Savings Account 2023-11-09
# 3    Shubh Savings Account 2023-11-13
# 43                   Day 5 2023-12-28
# 55   Two Wheeler Insurance 2024-01-23
# 53   Two Wheeler Insurance 2024-01-17
# 26                   Day 2 2023-12-20
# 23                   Day 1 2023-12-19
# 52  Four Wheeler Insurance 2024-01-17
# 56  Four Wheeler Insurance 2024-01-23
# 16                    DBTR 2023-12-18
# 28                    DBTR 2023-12-21
# 24                    DBTR 2023-12-19
# 29                    DBTR 2023-12-23
# 44                    DBTR 2023-12-29
# 37                    DBTR 2023-12-27
# 41                    DBTR 2023-12-28
# 25                    DBTR 2023-12-20
# 35                    DBTR 2023-12-26
#
#                                      Campaign Name  \
# 59                                           Day 1
# 2                              Dhanteras_Digi_Gold
# 45                                     Fancode OTT
# 5              100% cashback november_15thNov23_Mp
# 18                       Bhavishya_Newly_Onboarded
# 21                       Bhavishya_Newly_Onboarded
# 54                            English_annuity_pyot
# 31                       Bhavishya_Newly_Onboarded
# 10                            AS_Christmas_Bonanza
# 39                       Bhavishya_Newly_Onboarded
# 11                                       VR_PMJJBY
# 15                               Christmas_Bonanza
# 46                       Bhavishya_Newly_Onboarded
# 49                       Bhavishya_Newly_Onboarded
# 34                               Christmas_Bonanza
# 57                       Bhavishya Newly Onboarded
# 1                              Shubh Renewal Hindi
# 4                                Shubh Renewal Hin
# 8                        Bhavishya_newly_onboarded
# 12                             Balance_Buildup_MAB
# 14                             Balance_Buildup_Deb
# 13                             Balance_Buildup_MAB
# 20                             Balance_Buildup_MAB
# 27                      Balance_Buildup_Debit_Card
# 30                      Balance_Buildup_Debit_Card
# 36                             Balance_Buildup_MAB
# 42                      Balance_Buildup_Debit_Card
# 7                               rekyc through vkyc
# 19                              ReKyc_through_VKYC
# 33                              Rekyc_through_vkyc
# 38                              ReKyc_through_VKYC
# 9                                Bhavishya renewal
# 17                               Bhavishya_Renewal
# 22                               Bhavishya_Renewal
# 32                               Bhavishya_Renewal
# 40                              Bhavishya_Renewals
# 47                              Bhavishya_Renewals
# 50                              Bhavishya_Renewals
# 6   RCS campaigns for Funding and VKYC_16thNov22_1
# 51                                          Day_13
# 58                              Bhavishya Renewals
# 48                                           Day 9
# 0                                Shubh Renewal Eng
# 3                                Shubh Renewal Eng
# 43                                           Day 5
# 55                           Two Wheeler Insurance
# 53                           Two_wheeler_insurance
# 26                                           Day_2
# 23                                       CDP_Day_1
# 52                          four_wheeler_insurance
# 56                          Four Wheeler Insurance
# 16                                            DBTR
# 28                                            DBTR
# 24                                            DBTR
# 29                                            DBTR
# 44                                            DBTR
# 37                                            DBTR
# 41                                            DBTR
# 25                                            DBTR
# 35                                            DBTR
#
#                         Target Audience  \
# 59                        CDP Customers
# 2                      Active Customers
# 45                            CASA Dump
# 5                  FinoPay Refer & Earn
# 18                            Customers
# 21                            Customers
# 54                        Merchant Base
# 31                            Customers
# 10                            Merchants
# 39                            Customers
# 11                            Merchants
# 15                            Merchants
# 46  Bhavishya Newly Onboarded Customers
# 49  Bhavishya Newly Onboarded Customers
# 34                            Merchants
# 57  Bhavishya Newly Onboarded Customers
# 1                 Non Renewal Customers
# 4                 Non Renewal Customers
# 8             Newly Onboarded Customers
# 12                            Customers
# 14                            Customers
# 13                            Customers
# 20                            Customers
# 27                            Customers
# 30                            Customers
# 36                            Customers
# 42                            Customers
# 7               ReKyc Pending Customers
# 19                            Customers
# 33                            Customers
# 38                            Customers
# 9             Renewal Pending Customers
# 17                            Customers
# 22                            Customers
# 32                            Customers
# 40                            Customers
# 47         Bhavishya Renewals Customers
# 50         Bhavishya Renewals Customers
# 6                  Non Funded Customers
# 51                        CDP Customers
# 58         Bhavishya Renewals Customers
# 48                        CDP Customers
# 0                 Non Renewal Customers
# 3                 Non Renewal Customers
# 43                            Customers
# 55                       Insurance Base
# 53                       Insurance Base
# 26                            Customers
# 23                            Customers
# 52                       Insurance Base
# 56                       Insurance Base
# 16                         Distributors
# 28                         Distributors
# 24                         Distributors
# 29                         Distributors
# 44                         Distributors
# 37                         Distributors
# 41                         Distributors
# 25                         Distributors
# 35                         Distributors
#
#                                               Message  Total  Delivered  \
# 59  निर्बाध और सुविधाजनक बैंकिंग का आनंद लेने के ल...  89310      80605
# 2                                                 NaN  49949      47461
# 45  Download FinoPay App! Make a transaction of Rs...  48786      44927
# 5                                                 NaN  33195      32201
# 18  "पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिन...  32943      30760
# 21  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...  32424      30293
# 54  KHATA KHOLNE KE SAATH AUR BAAD, SADAIV SAATH. ...  31364      30369
# 31  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...  31348      29566
# 10  This December,\nEarn big with Christmas Bonanz...  31159      30230
# 39  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...  30758      29147
# 11  Pradhan Mantri Jeevann Jyoti Bima Yojana (PMJJ...  30184      29289
# 15  This December,\nEarn big with Christmas Bonanz...  29969      28630
# 46  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...  29813      31213
# 49  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...  29190      26086
# 34  "This December,\nEarn big with Christmas Bonan...  29114      28403
# 57  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...  28675      26582
# 1                                                 NaN  28118      26191
# 4                                                 NaN  26841      24800
# 8                                                 NaN  24763      22795
# 12  Maintain Balance of Rs.2000 and above, till 31...  22289      21175
# 14  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...  21892      20570
# 13  Maintain Balance of Rs.2000 and above, till 31...  21891      20623
# 20  Maintain Balance of Rs.2000 and above, till 31...  21489      20441
# 27  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...  21402        812
# 30  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...  21161      20302
# 36  Maintain Balance of Rs.2000 and above, till 31...  20882      20115
# 42  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...  20826      20002
# 7                                                 NaN  20175      19027
# 19  "Dear Customer,\nRe-activate your Account with...  17715      16701
# 33  Dear Customer,\r\nRe-activate your Account wit...  17537      16575
# 38  Dear Customer,\r\nRe-activate your Account wit...  17473      16671
# 9                                                 NaN  14231      13301
# 17  """पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफ...  14216      13544
# 22  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...  13979      13194
# 32  "पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिन...  13563      12936
# 40  "पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिन...  13300      12729
# 47  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...  12945      14798
# 50  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...  12719      11895
# 6                                                 NaN  10982      10229
# 51  लेनदेन के लिए अपने रुपे डेबिट कार्ड का उपयोग क...  10747       9230
# 58  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...   6567       6175
# 48  अब नजदीकी मर्चेंट प्वाइंट पर जाकर आसानी से अपन...   5697       5839
# 0                                                 NaN   4133       3870
# 3                                                 NaN   3933       3683
# 43  फिनोपे पर यूपीआई सक्रिय करें और निर्बाध रूप से...   2865       2591
# 55  Apni gadi ka insurance karva liya? Rs. 2000 ke...   2094       2024
# 53  Apni gadi ka insurance karva liya? Rs. 2000 ke...   2079       1986
# 26   अब अपने बचत खाते की शेष राशि पर 7.5% तक का अध...   1823       1651
# 23  निर्बाध और सुविधाजनक बैंकिंग का आनंद लेने के ल...   1683       1503
# 52  Motor Insurance Policy Dues ? Dear customer, Y...    165        160
# 56  Motor Insurance Policy Dues ? Dear customer, Y...    164        160
# 16  Please activate your inactive merchants in thi...     83         81
# 28  Please activate your inactive merchants in thi...     82         82
# 24  Please activate your inactive merchants in thi...     81         72
# 29  Please activate your inactive merchants in thi...     80         77
# 44  Please activate your inactive merchants in thi...     80          4
# 37  Please activate your inactive merchants in thi...     79         34
# 41  Please activate your inactive merchants in thi...     79          3
# 25  Please activate your inactive merchants in thi...     79         31
# 35  Please activate your inactive merchants in thi...     77         74
#
#      Read  Failed  Pending     Status       Rate        Day
# 59  22452    8706       -1    Running  27.854351    Tuesday
# 34                               Christmas_Bonanza
# 27                      Balance_Buildup_Debit_Card
# 28                                            DBTR
# 8                        Bhavishya_newly_onboarded
# 25                                            DBTR
# 29                                            DBTR
# 43                                           Day 5
# 20                             Balance_Buildup_MAB
# 18                       Bhavishya_Newly_Onboarded
# 15                               Christmas_Bonanza
# 48                                           Day 9
# 36                             Balance_Buildup_MAB
# 59                                           Day 1
# 26                                           Day_2
# 23                                       CDP_Day_1
# 3                                Shubh Renewal Eng
# 17                               Bhavishya_Renewal
# 14                             Balance_Buildup_Deb
# 44                                            DBTR
# 9                                Bhavishya renewal
# 7                               rekyc through vkyc
# 19                              ReKyc_through_VKYC
# 30                      Balance_Buildup_Debit_Card
# 6   RCS campaigns for Funding and VKYC_16thNov22_1
# 37                                            DBTR
# 4                                Shubh Renewal Hin
# 38                              ReKyc_through_VKYC
# 42                      Balance_Buildup_Debit_Card
# 33                              Rekyc_through_vkyc
# 21                       Bhavishya_Newly_Onboarded
# 31                       Bhavishya_Newly_Onboarded
# 39                       Bhavishya_Newly_Onboarded
# 46                       Bhavishya_Newly_Onboarded
# 49                       Bhavishya_Newly_Onboarded
# 32                               Bhavishya_Renewal
# 58                              Bhavishya Renewals
# 22                               Bhavishya_Renewal
# 50                              Bhavishya_Renewals
# 40                              Bhavishya_Renewals
# 47                              Bhavishya_Renewals
# 41                                            DBTR
#
#                         Target Audience  \
# 12                            Customers
# 54                        Merchant Base
# 16                         Distributors
# 10                            Merchants
# 24                         Distributors
# 11                            Merchants
# 56                       Insurance Base
# 53                       Insurance Base
# 2                      Active Customers
# 0                 Non Renewal Customers
# 1                 Non Renewal Customers
# 45                            CASA Dump
# 13                            Customers
# 5                  FinoPay Refer & Earn
# 55                       Insurance Base
# 52                       Insurance Base
# 51                        CDP Customers
# 57  Bhavishya Newly Onboarded Customers
# 35                         Distributors
# 34                            Merchants
# 27                            Customers
# 28                         Distributors
# 8             Newly Onboarded Customers
# 25                         Distributors
# 29                         Distributors
# 43                            Customers
# 20                            Customers
# 18                            Customers
# 15                            Merchants
# 48                        CDP Customers
# 36                            Customers
# 59                        CDP Customers
# 26                            Customers
# 23                            Customers
# 3                 Non Renewal Customers
# 17                            Customers
# 14                            Customers
# 44                         Distributors
# 9             Renewal Pending Customers
# 7               ReKyc Pending Customers
# 19                            Customers
# 30                            Customers
# 6                  Non Funded Customers
# 37                         Distributors
# 4                 Non Renewal Customers
# 38                            Customers
# 42                            Customers
# 33                            Customers
# 21                            Customers
# 31                            Customers
# 39                            Customers
# 46  Bhavishya Newly Onboarded Customers
# 49  Bhavishya Newly Onboarded Customers
# 32                            Customers
# 58         Bhavishya Renewals Customers
# 22                            Customers
# 50         Bhavishya Renewals Customers
# 40                            Customers
# 47         Bhavishya Renewals Customers
# 41                         Distributors
#
#                                               Message  Total  Delivered  \
# 12  Maintain Balance of Rs.2000 and above, till 31...  22289      21175
# 54  KHATA KHOLNE KE SAATH AUR BAAD, SADAIV SAATH. ...  31364      30369
# 16  Please activate your inactive merchants in thi...     83         81
# 10  This December,\nEarn big with Christmas Bonanz...  31159      30230
# 24  Please activate your inactive merchants in thi...     81         72
# 11  Pradhan Mantri Jeevann Jyoti Bima Yojana (PMJJ...  30184      29289
# 56  Motor Insurance Policy Dues ? Dear customer, Y...    164        160
# 53  Apni gadi ka insurance karva liya? Rs. 2000 ke...   2079       1986
# 2                                                 NaN  49949      47461
# 0                                                 NaN   4133       3870
# 1                                                 NaN  28118      26191
# 45  Download FinoPay App! Make a transaction of Rs...  48786      44927
# 13  Maintain Balance of Rs.2000 and above, till 31...  21891      20623
# 5                                                 NaN  33195      32201
# 55  Apni gadi ka insurance karva liya? Rs. 2000 ke...   2094       2024
# 52  Motor Insurance Policy Dues ? Dear customer, Y...    165        160
# 51  लेनदेन के लिए अपने रुपे डेबिट कार्ड का उपयोग क...  10747       9230
# 57  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...  28675      26582
# 35  Please activate your inactive merchants in thi...     77         74
# 34  "This December,\nEarn big with Christmas Bonan...  29114      28403
# 27  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...  21402        812
# 28  Please activate your inactive merchants in thi...     82         82
# 8                                                 NaN  24763      22795
# 25  Please activate your inactive merchants in thi...     79         31
# 29  Please activate your inactive merchants in thi...     80         77
# 43  फिनोपे पर यूपीआई सक्रिय करें और निर्बाध रूप से...   2865       2591
# 20  Maintain Balance of Rs.2000 and above, till 31...  21489      20441
# 18  "पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिन...  32943      30760
# 15  This December,\nEarn big with Christmas Bonanz...  29969      28630
# 48  अब नजदीकी मर्चेंट प्वाइंट पर जाकर आसानी से अपन...   5697       5839
# 36  Maintain Balance of Rs.2000 and above, till 31...  20882      20115
# 59  निर्बाध और सुविधाजनक बैंकिंग का आनंद लेने के ल...  89310      80605
# 26   अब अपने बचत खाते की शेष राशि पर 7.5% तक का अध...   1823       1651
# 23  निर्बाध और सुविधाजनक बैंकिंग का आनंद लेने के ल...   1683       1503
# 3                                                 NaN   3933       3683
# 17  """पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफ...  14216      13544
# 14  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...  21892      20570
# 44  Please activate your inactive merchants in thi...     80          4
# 9                                                 NaN  14231      13301
# 7                                                 NaN  20175      19027
# 19  "Dear Customer,\nRe-activate your Account with...  17715      16701
# 30  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...  21161      20302
# 6                                                 NaN  10982      10229
# 37  Please activate your inactive merchants in thi...     79         34
# 4                                                 NaN  26841      24800
# 38  Dear Customer,\r\nRe-activate your Account wit...  17473      16671
# 42  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...  20826      20002
# 33  Dear Customer,\r\nRe-activate your Account wit...  17537      16575
# 21  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...  32424      30293
# 31  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...  31348      29566
# 39  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...  30758      29147
# 46  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...  29813      31213
# 49  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...  29190      26086
# 32  "पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिन...  13563      12936
# 58  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...   6567       6175
# 22  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...  13979      13194
# 50  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...  12719      11895
# 40  "पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिन...  13300      12729
# 47  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की
0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
data = {'Message': [
    'निर्बाध और सुविधाजनक बैंकिंग का आनंद लेने के ल.',
    'This December, Earn big with Christmas Bonanz...',
    'KHATA KHOLNE KE SAATH AUR BAAD, SADAIV SAATH.'
],
    'Category': [0, 1, 2]
}

df = pd.DataFrame(data)
df['tokens'] = df['Message'].apply(nltk.word_tokenize)
df['cleaned_message'] = df['tokens'].apply(lambda x: ' '.join(x))
tfidf_vectorizer = TfidfVectorizer()
X = tfidf_vectorizer.fit_transform(df['cleaned_message'])
X_train, X_test, y_train, y_test = train_test_split(X, df['Category'], test_size=0.2, random_state=42)
clf = MultinomialNB()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:\n', classification_rep)
# Out:
# Accuracy: 0.00
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            2       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       1.0
#    macro avg       0.00      0.00      0.00       1.0
# weighted avg       0.00      0.00      0.00       1.0
# /Users/aayushjain/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aayushjain/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aayushjain/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aayushjain/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aayushjain/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aayushjain/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product          60 non-null     object
#  1   Date             60 non-null     datetime64[ns]
#  2   Campaign Name    60 non-null     object
#  3   Target Audience  60 non-null     object
#  4   Message          50 non-null     object
#  5   Total            60 non-null     int64
#  6   Delivered        60 non-null     int64
#  7   Read             60 non-null     int64
#  8   Failed           60 non-null     int64
#  9   Pending          60 non-null     int64
#  10  Status           60 non-null     object
#  11  Rate             60 non-null     float64
#  12  Day              60 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(6)
# memory usage: 6.2+ KB

# %%
# !pip install langid
import langid
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langid
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 6.4 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/aayushjain/Library/Python/3.9/lib/python/site-packages (from langid) (1.24.3)
# Building wheels for collected packages: langid
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941187 sha256=60ab6a3644e332f14939da9031545827aff932a551254498ca4e224ca78acc23
#   Stored in directory: /Users/aayushjain/Library/Caches/pip/wheels/93/95/a9/c292c9dd8cadb8f2359f1670ff198a40d47167b0be3236e1c8
# Successfully built langid
# Installing collected packages: langid
# Successfully installed langid-1.1.6
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
def classify_language(message):
    if isinstance(message, str): 
        lang, _ = langid.classify(message)
        if lang == 'hi':
            return 0  # Hindi written in Devanagari
        elif lang == 'en':
            return 2  # English written in English
        else:
            return 1  # Hindi written in English
    else:
        return np.nan  # Handle NaN values

rcs['Language_Category'] = rcs['Message'].apply(classify_language)

# %%
rcs[['Language_Category','Message']]
# Out:
#     Language_Category                                            Message
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# 5                 NaN                                                NaN
# 6                 NaN                                                NaN
# 7                 NaN                                                NaN
# 8                 NaN                                                NaN
# 9                 NaN                                                NaN
# 10                2.0  This December,\nEarn big with Christmas Bonanz...
# 11                2.0  Pradhan Mantri Jeevann Jyoti Bima Yojana (PMJJ...
# 12                2.0  Maintain Balance of Rs.2000 and above, till 31...
# 13                2.0  Maintain Balance of Rs.2000 and above, till 31...
# 14                0.0  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...
# 15                2.0  This December,\nEarn big with Christmas Bonanz...
# 16                2.0  Please activate your inactive merchants in thi...
# 17                0.0  """पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफ...
# 18                0.0  "पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिन...
# 19                2.0  "Dear Customer,\nRe-activate your Account with...
# 20                2.0  Maintain Balance of Rs.2000 and above, till 31...
# 21                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...
# 22                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...
# 23                0.0  निर्बाध और सुविधाजनक बैंकिंग का आनंद लेने के ल...
# 24                2.0  Please activate your inactive merchants in thi...
# 25                2.0  Please activate your inactive merchants in thi...
# 26                0.0   अब अपने बचत खाते की शेष राशि पर 7.5% तक का अध...
# 27                0.0  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...
# 28                2.0  Please activate your inactive merchants in thi...
# 29                2.0  Please activate your inactive merchants in thi...
# 30                0.0  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...
# 31                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...
# 32                0.0  "पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिन...
# 33                2.0  Dear Customer,\r\nRe-activate your Account wit...
# 34                2.0  "This December,\nEarn big with Christmas Bonan...
# 35                2.0  Please activate your inactive merchants in thi...
# 36                2.0  Maintain Balance of Rs.2000 and above, till 31...
# 37                2.0  Please activate your inactive merchants in thi...
# 38                2.0  Dear Customer,\r\nRe-activate your Account wit...
# 39                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिनो...
# 40                0.0  "पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य!\r\nफिन...
# 41                2.0  Please activate your inactive merchants in thi...
# 42                0.0  **₹2 लाख* तक का बीमा कवर और *₹25* का अतिरिक्त ...
# 43                0.0  फिनोपे पर यूपीआई सक्रिय करें और निर्बाध रूप से...
# 44                2.0  Please activate your inactive merchants in thi...
# 45                2.0  Download FinoPay App! Make a transaction of Rs...
# 46                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...
# 47                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...
# 48                0.0  अब नजदीकी मर्चेंट प्वाइंट पर जाकर आसानी से अपन...
# 49                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...
# 50                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...
# 51                0.0  लेनदेन के लिए अपने रुपे डेबिट कार्ड का उपयोग क...
# 52                2.0  Motor Insurance Policy Dues ? Dear customer, Y...
# 53                1.0  Apni gadi ka insurance karva liya? Rs. 2000 ke...
# 54                2.0  KHATA KHOLNE KE SAATH AUR BAAD, SADAIV SAATH. ...
# 55                1.0  Apni gadi ka insurance karva liya? Rs. 2000 ke...
# 56                2.0  Motor Insurance Policy Dues ? Dear customer, Y...
# 57                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...
# 58                0.0  पाएं तेज़ दिमाग के साथ सुरक्षित भविष्य! फिनो की...
# 59                0.0  निर्बाध और सुविधाजनक बैंकिंग का आनंद लेने के ल...

# %%
rcs[rcs['Language_Category']==1]
# Out:
#                   Product       Date          Campaign Name Target Audience  \
# 53  Two Wheeler Insurance 2024-01-17  Two_wheeler_insurance  Insurance Base
# 55  Two Wheeler Insurance 2024-01-23  Two Wheeler Insurance  Insurance Base
#
#                                               Message  Total  Delivered  Read  \
# 53  Apni gadi ka insurance karva liya? Rs. 2000 ke...   2079       1986   681
# 55  Apni gadi ka insurance karva liya? Rs. 2000 ke...   2094       2024   651
#
#     Failed  Pending     Status       Rate        Day  Language_Category
# 53      93        0  Completed  34.290030  Wednesday                1.0
# 55      70        0  Completed  32.164032    Tuesday                1.0

# %%
lang_classified = rcs.groupby('Language_Category')['Rate'].mean().reset_index()
plt.figure(figsize=(11, 6))
plt.bar(lang_classified['Language_Category'],lang_classified['Rate'], color=company_colors[2])
plt.title('Average Rate by Language')
plt.xlabel('Typpes of Languages')
plt.xticks(rotation='vertical')
plt.ylabel('Average Rate')
plt.show()

# %% [markdown]
# find avg count of insurace and category

# %% [markdown]
# 0 represents Hindi written in devnagri
# 1 represents Hindi written in English
# 2 represents Enlish written in english
#
# Need customer data to know the average age group of user.
