# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
ct= pd.read_csv('Fino Dataset- Aayush - CT (1).csv')
meta=pd.read_csv('Fino Dataset- Aayush - meta.csv')
rcs=pd.read_csv('Fino Dataset- Aayush - rcs.csv')
whatsapp=pd.read_csv('Fino Dataset- Aayush - whatsapp.csv')

# %%
ct.head()
# Out:
#    SI number             Product Campaign Owner    Platform              Date  \
# 0          1  Shopkeepers Policy        Shriya   CT (Mitra)  Nov 30, 10:40 AM
# 1          2             FinoPay        Shriya   CT (Mitra)   Nov 23, 2:00 PM
# 2          3   Become a Merchant        Shriya   CT (Mitra)   Nov 21, 6:00 PM
# 3          4  Shopkeepers Policy        Shriya   CT (Mitra)  Nov 21, 12:37 PM
# 4          5     Suvidha Account        Shriya   CT (Mitra)  Nov 21, 12:00 AM
#
#                                        Campaign Name Target Audience  \
# 0                               VR:Shopkeeper_Policy             NaN
# 1                                       AB1:Upi _Txn             NaN
# 2            AB1:Become_a_Merchant_No_Cif_Have_Token             NaN
# 3                               VR:Shopkeeper_Policy             NaN
# 4  HM:suvidha_Merchant_notifcation__Nov'23 (21st ...             NaN
#
#         Sent Engaged (Notification Viewed)  Rate             Status  \
# ...

# %%
ct.head()
# Out:
#    SI number             Product Campaign Owner    Platform              Date  \
# 0          1  Shopkeepers Policy        Shriya   CT (Mitra)  Nov 30, 10:40 AM
# 1          2             FinoPay        Shriya   CT (Mitra)   Nov 23, 2:00 PM
# 2          3   Become a Merchant        Shriya   CT (Mitra)   Nov 21, 6:00 PM
# 3          4  Shopkeepers Policy        Shriya   CT (Mitra)  Nov 21, 12:37 PM
# 4          5     Suvidha Account        Shriya   CT (Mitra)  Nov 21, 12:00 AM
#
#                                        Campaign Name Target Audience  \
# 0                               VR:Shopkeeper_Policy             NaN
# 1                                       AB1:Upi _Txn             NaN
# 2            AB1:Become_a_Merchant_No_Cif_Have_Token             NaN
# 3                               VR:Shopkeeper_Policy             NaN
# 4  HM:suvidha_Merchant_notifcation__Nov'23 (21st ...             NaN
#
#         Sent Engaged (Notification Viewed)  Rate             Status  \
# ...

# %%
ct= ct.drop(['SI number','Business Impact'],axis=1)

# %%
ct.head()
# Out:
#               Product Campaign Owner    Platform              Date  \
# 0  Shopkeepers Policy        Shriya   CT (Mitra)  Nov 30, 10:40 AM
# 1             FinoPay        Shriya   CT (Mitra)   Nov 23, 2:00 PM
# 2   Become a Merchant        Shriya   CT (Mitra)   Nov 21, 6:00 PM
# 3  Shopkeepers Policy        Shriya   CT (Mitra)  Nov 21, 12:37 PM
# 4     Suvidha Account        Shriya   CT (Mitra)  Nov 21, 12:00 AM
#
#                                        Campaign Name Target Audience  \
# 0                               VR:Shopkeeper_Policy             NaN
# 1                                       AB1:Upi _Txn             NaN
# 2            AB1:Become_a_Merchant_No_Cif_Have_Token             NaN
# 3                               VR:Shopkeeper_Policy             NaN
# 4  HM:suvidha_Merchant_notifcation__Nov'23 (21st ...             NaN
#
#         Sent Engaged (Notification Viewed)  Rate             Status
# 0     28,974                             4  0.01          Completed
# ...

# %%
ct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Product                        148 non-null    object
#  1   Campaign Owner                 148 non-null    object
#  2   Platform                       148 non-null    object
#  3   Date                           148 non-null    object
#  4   Campaign Name                  148 non-null    object
#  5   Target Audience                125 non-null    object
#  6   Sent                           148 non-null    object
#  7   Engaged (Notification Viewed)  148 non-null    object
#  8   Rate                           148 non-null    object
#  9   Status                         148 non-null    object
# dtypes: object(10)
# memory usage: 11.7+ KB

# %%
ct['Status'].unique()
# Out:
# array(['Completed', 'Awaiting Next Run', 'Running'], dtype=object)

# %%
ct['Campaign Owner'].unique()
# Out:
# array(['Shriya ', 'Ajay', 'Shriya', 'Shruti Tripathi', 'Sachin Belose'],
#       dtype=object)

# %%
ct['Sent'] = pd.to_numeric(ct['Sent'].str.replace(',', ''), errors='coerce')
ct['Engaged (Notification Viewed)'] = pd.to_numeric(ct['Engaged (Notification Viewed)'].str.replace(',', ''), errors='coerce')
ct['Rate'] = pd.to_numeric(ct['Rate'], errors='coerce')

# %%
df_sorted = ct.sort_values(by='Rate', ascending=False)
df_sorted.head(25)
# Out:
#                      Product   Campaign Owner      Platform              Date  \
# 127    VKYC Completing nudge           Shriya  CT (FinoPay)   Dec 26, 5:02 PM
# 48                   UPI Txn  Shruti Tripathi  CT (FinoPay)   Dec 13, 3:07 PM
# 124    VKYC initiation nudge           Shriya  CT (FinoPay)   Dec 26, 2:16 PM
# 13           Go Digit Health           Shriya  CT (FinoPay)   Nov 29, 8:00 PM
# 133          Birthday Wishes           Shriya  CT (FinoPay)  Jan 24, 12:45 PM
# 143   Makar Sankranti Wishes           Shriya  CT (FinoPay)  Jan 15, 10:00 AM
# 142             Lohri Wishes           Shriya  CT (FinoPay)  Jan 15, 10:09 AM
# 141         Magh Bihu Wishes           Shriya  CT (FinoPay)  Jan 16, 10:00 AM
# 140      Surya Pongal Wishes           Shriya  CT (FinoPay)  Jan 16, 10:00 AM
# 138      Mattu Pongal Wishes           Shriya  CT (FinoPay)  Jan 17, 10:00 AM
# 125        App Install Nudge           Shriya  CT (FinoPay)   Dec 26, 2:52 PM
# ...

# %%
print(ct['Rate'].mean())
print(ct['Engaged (Notification Viewed)'].mean())
# Out:
# 1.737017543859649
# 3600.141891891892

# %%
filtered_data = ct[(ct['Rate'] > 1.73) & (ct['Engaged (Notification Viewed)'] > 3600)]
filtered_data.head(10)
# Out:
#                      Product Campaign Owner      Platform              Date  \
# 35       Balance Buildup MAB         Shriya  CT (FinoPay)   Dec 11, 3:25 PM
# 97         Connect CC to UPI  Sachin Belose  CT (FinoPay)  Dec 23, 10:30 AM
# 132  Motor Insurance*FinoPay         Shriya  CT (FinoPay)   Jan 24, 2:36 PM
# 137                 Krazybee         Shriya  CT (FinoPay)  Jan 18, 12:12 PM
# 142             Lohri Wishes         Shriya  CT (FinoPay)  Jan 15, 10:09 AM
# 143   Makar Sankranti Wishes         Shriya  CT (FinoPay)  Jan 15, 10:00 AM
#
#                                          Campaign Name    Target Audience  \
# 35                                  AM:Balance_Buildup          Customers
# 97                                      CC on fino pay          Customers
# 132           SB/VR:Motor Insurance_FinoPay_Collab\n\n  All FinoPay Users
# 137  PL:KrazyBee\n\nSM\n ID: 1705560150 \nCreated b...     Loan customers
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)  # Set the precision you desire

# %%
ct["Target Audience"].unique()
# Out:
# array([nan, 'Merchant', 'Customers', 'All FinoPay Users', 'C19',
#        'Newly Onboarded Customers', 'Renewal Customers', 'Loan customers',
#        'Dropoffs'], dtype=object)

# %%
import pandas as pd

# Assuming 'ct' is your DataFrame
unique_values = ct['Target Audience'].unique()

# Create a dictionary to store DataFrames for each unique value
dfs_by_target_audience = {}

# Split the DataFrame based on unique values
for value in unique_values:
    dfs_by_target_audience[value] = ct[ct['Target Audience'] == value]

# Access individual DataFrames using the unique values
for value, df in dfs_by_target_audience.items():
    print(f"DataFrame for Target Audience: {value}")
    print(df)
    print("=" * 50)
# Out:
# DataFrame for Target Audience: nan
# Empty DataFrame
# Columns: [Product, Campaign Owner, Platform, Date, Campaign Name, Target Audience, Sent, Engaged (Notification Viewed), Rate, Status, Time]
# Index: []
# ...
# DataFrame for Target Audience: Merchant
#                          Product Campaign Owner         Platform        Date  \
# 23           CASA Cashback Offer         Shriya  CT (Fino Mitra)  1900-12-01
# 24                    Do Pe Tees         Shriya  CT (Fino Mitra)  1900-12-01
# 25                      MATM AMC         Shriya  CT (Fino Mitra)  1900-12-01
# 26                  AePS Winback         Shriya  CT (Fino Mitra)  1900-12-02
# 27   Shubh Savings Account Offer         Shriya  CT (Fino Mitra)  1900-12-02
# ..                           ...            ...              ...         ...
# 119  Go Digit Health (Insurance)         Shriya  CT (Fino Mitra)  1900-12-30
# 120  Go Digit Health (Insurance)         Shriya  CT (Fino Mitra)  1900-12-30
# ...

# %%
ct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Product                        148 non-null    object
#  1   Campaign Owner                 148 non-null    object
#  2   Platform                       148 non-null    object
#  3   Date                           148 non-null    object
#  4   Campaign Name                  148 non-null    object
#  5   Target Audience                125 non-null    object
#  6   Sent                           148 non-null    int64
#  7   Engaged (Notification Viewed)  148 non-null    int64
#  8   Rate                           114 non-null    float64
#  9   Status                         148 non-null    object
#  10  Time                           148 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(7)
# memory usage: 12.8+ KB

# %%
ct = ct.drop(['Campaign Owner'],axis=1)

# %%
len(ct["Product"].unique())
#48 unique products for count of 149
#3 platforms mitra, finopay and fino mitra.
# Out:
# 48

# %%
ct["Rate"].count()
# Out:
# 114
