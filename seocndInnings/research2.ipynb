# %%
import pandas as pd 
import numpy as np

# %%
dataset=pd.read_excel('/Users/aayushjain/codes/projects/company assignements/Fino/seocndInnings/spicemoneyred.xlsx')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2831 entries, 0 to 2830
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Source        2831 non-null   object
#  1   Screenname    2828 non-null   object
#  2   Display Name  2828 non-null   object
#  3   Sentiment     2831 non-null   object
#  4   Content       2822 non-null   object
# dtypes: object(5)
# memory usage: 110.7+ KB

# %%
dataset_red=dataset[['Source','Screenname','Sentiment','Content']]

# %%
dataset_red.head()
# Out:
#      Source          Screenname Sentiment  \
# 0   Youtube  @manipurkangleipak   Neutral
# 1   Youtube     @gangakumar4607  Positive
# 2   Youtube       @dalisahu1510   Neutral
# 3  Facebook             FB User   Neutral
# 4  Facebook             FB User   Neutral
#
#                                              Content
# 0  I had already completed my IIBF BC Certificate...
# 1  ❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤...
# 2          ट्रेनिंग कब शुरू होगा जानकारी कैसे मिलेगी
# 3                   Call karke bataye sir 9414927544
# 4                                  I'd kitne m banga

# %%
dataset_red['Content'].nunique()
# Out:
# 2593

# %%
dataset_red.drop_duplicates()
# Out:
#         Source          Screenname Sentiment  \
# 0      Youtube  @manipurkangleipak   Neutral
# 1      Youtube     @gangakumar4607  Positive
# 2      Youtube       @dalisahu1510   Neutral
# 3     Facebook             FB User   Neutral
# 4     Facebook             FB User   Neutral
# ...        ...                 ...       ...
# 2825  Facebook             FB User  Positive
# 2826  Facebook             FB User  Positive
# 2828      News                 NaN   Neutral
# 2829      News                 NaN   Neutral
# 2830      News                 NaN  Positive
#
#                                                 Content
# 0     I had already completed my IIBF BC Certificate...
# 1     ❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤...
# 2             ट्रेनिंग कब शुरू होगा जानकारी कैसे मिलेगी
# 3                      Call karke bataye sir 9414927544
# 4                                     I'd kitne m banga
# ...                                                 ...
# ...

# %%
dataset_red.dropna(inplace=True)
# Out:
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_7315/1575909962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_red.dropna(inplace=True)

# %%
text = " ".join(comment for comment in dataset_red['Content'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 text = " ".join(comment for comment in dataset_red['Content'])
#
# TypeError: sequence item 34: expected str instance, int found

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Combine all the content into a single string
text = " ".join(str(comment) for comment in dataset_red['Content'] if pd.notnull(comment))

# Create a WordCloud instance
wordcloud = WordCloud(
    width=800, 
    height=400, 
    background_color='white', 
    colormap='viridis', 
    max_words=200, 
    stopwords=None  # Add your stopwords list if needed
).generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")  # No axes
plt.show()
